# %% [markdown]
# ### 1. Teleoperation with Keyboard

# %%
import numpy as np
from PIL import Image
from mujoco_env.y_env import SimpleEnv

# %%
xml_path = './asset/trossen_vx300s/scene.xml'
PnPEnv = SimpleEnv(xml_path, seed = 0, state_type = 'joint_angle')
new_plate_pos = np.array([0.5, 0.2, 0.0])
new_mug_pos = np.array([0.9, -0.2, 0.0]) 
PnPEnv.set_obj_pose(p_mug=new_mug_pos, p_plate=new_plate_pos)

action = np.zeros(7)
# Out:
# -----------------------------------------------------------------------------
# name:[Tabletop] dt:[0.002] HZ:[500]
#  n_qpos:[22] n_qvel:[20] n_qacc:[20] n_ctrl:[7]
#  integrator:[EULER]
#
# n_body:[16]
#  [0/16] [world] mass:[0.00]kg
#  [1/16] [base_link] mass:[0.97]kg
#  [2/16] [shoulder_link] mass:[0.80]kg
#  [3/16] [upper_arm_link] mass:[0.79]kg
#  [4/16] [upper_forearm_link] mass:[0.32]kg
#  [5/16] [lower_forearm_link] mass:[0.41]kg
#  [6/16] [wrist_link] mass:[0.12]kg
#  [7/16] [gripper_link] mass:[0.25]kg
#  [8/16] [gripper_prop_link] mass:[0.01]kg
#  [9/16] [left_finger_link] mass:[0.03]kg
#  [10/16] [right_finger_link] mass:[0.03]kg
#  [11/16] [ego_cam_body] mass:[0.00]kg
#  [12/16] [body_obj_mug_5] mass:[0.00]kg
#  [13/16] [object_mug_5] mass:[0.08]kg
#  [14/16] [body_obj_plate_11] mass:[0.00]kg
#  [15/16] [object_plate_11] mass:[0.10]kg
# body_total_mass:[3.93]kg
#
# n_geom:[105]
# geom_names:['floor', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'left_finger_pad_0', 'left_finger_pad_1', 'left_finger_pad_2', 'left_finger_pad_3', 'left_finger_pad_4', 'left_finger_pad_5', 'left_finger_pad_6', 'left_finger_pad_7', 'left_finger_pad_8', None, 'right_finger_pad_0', 'right_finger_pad_1', 'right_finger_pad_2', 'right_finger_pad_3', 'right_finger_pad_4', 'right_finger_pad_5', 'right_finger_pad_6', 'right_finger_pad_7', 'right_finger_pad_8', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# n_mesh:[76]
# mesh_names:['vx300s_1_base', 'vx300s_2_shoulder', 'vx300s_3_upper_arm', 'vx300s_4_upper_forearm', 'vx300s_5_lower_forearm', 'vx300s_6_wrist', 'vx300s_7_gripper', 'vx300s_8_gripper_prop', 'vx300s_9_gripper_bar', 'vx300s_10_gripper_finger', 'mug_5_normalized_0_vis', 'mug_5_normalized_collision_22._coll', 'mug_5_normalized_collision_23._coll', 'mug_5_normalized_collision_21._coll', 'mug_5_normalized_collision_20._coll', 'mug_5_normalized_collision_24._coll', 'mug_5_normalized_collision_30._coll', 'mug_5_normalized_collision_18._coll', 'mug_5_normalized_collision_19._coll', 'mug_5_normalized_collision_31._coll', 'mug_5_normalized_collision_25._coll', 'mug_5_normalized_collision_27._coll', 'mug_5_normalized_collision_26._coll', 'mug_5_normalized_collision_9._coll', 'mug_5_normalized_collision_8._coll', 'mug_5_normalized_collision_6._coll', 'mug_5_normalized_collision_7._coll', 'mug_5_normalized_collision_5._coll', 'mug_5_normalized_collision_4._coll', 'mug_5_normalized_collision_0._coll', 'mug_5_normalized_collision_1._coll', 'mug_5_normalized_collision_3._coll', 'mug_5_normalized_collision_2._coll', 'mug_5_normalized_collision_17._coll', 'mug_5_normalized_collision_16._coll', 'mug_5_normalized_collision_28._coll', 'mug_5_normalized_collision_14._coll', 'mug_5_normalized_collision_15._coll', 'mug_5_normalized_collision_29._coll', 'mug_5_normalized_collision_11._coll', 'mug_5_normalized_collision_10._coll', 'mug_5_normalized_collision_12._coll', 'mug_5_normalized_collision_13._coll', 'plate_11_normalized_0_vis', 'plate_11_normalized_collision_22._coll', 'plate_11_normalized_collision_23._coll', 'plate_11_normalized_collision_21._coll', 'plate_11_normalized_collision_20._coll', 'plate_11_normalized_collision_24._coll', 'plate_11_normalized_collision_30._coll', 'plate_11_normalized_collision_18._coll', 'plate_11_normalized_collision_19._coll', 'plate_11_normalized_collision_31._coll', 'plate_11_normalized_collision_25._coll', 'plate_11_normalized_collision_27._coll', 'plate_11_normalized_collision_26._coll', 'plate_11_normalized_collision_9._coll', 'plate_11_normalized_collision_8._coll', 'plate_11_normalized_collision_6._coll', 'plate_11_normalized_collision_7._coll', 'plate_11_normalized_collision_5._coll', 'plate_11_normalized_collision_4._coll', 'plate_11_normalized_collision_0._coll', 'plate_11_normalized_collision_1._coll', 'plate_11_normalized_collision_3._coll', 'plate_11_normalized_collision_2._coll', 'plate_11_normalized_collision_17._coll', 'plate_11_normalized_collision_16._coll', 'plate_11_normalized_collision_28._coll', 'plate_11_normalized_collision_14._coll', 'plate_11_normalized_collision_15._coll', 'plate_11_normalized_collision_29._coll', 'plate_11_normalized_collision_11._coll', 'plate_11_normalized_collision_10._coll', 'plate_11_normalized_collision_12._coll', 'plate_11_normalized_collision_13._coll']
#
# n_joint:[10]
#  [0/10] [waist] axis:[0. 0. 1.]
#  [1/10] [shoulder] axis:[0. 1. 0.]
#  [2/10] [elbow] axis:[0. 1. 0.]
#  [3/10] [forearm_roll] axis:[1. 0. 0.]
#  [4/10] [wrist_angle] axis:[0. 1. 0.]
#  [5/10] [wrist_rotate] axis:[1. 0. 0.]
#  [6/10] [left_finger] axis:[0. 1. 0.]
#  [7/10] [right_finger] axis:[0. 1. 0.]
#  [8/10] [None] axis:[0. 0. 1.]
#  [9/10] [None] axis:[0. 0. 1.]
#
# n_dof:[20] (=number of rows of Jacobian)
#  [0/20] [None] attached joint:[waist] body:[shoulder_link]
#  [1/20] [None] attached joint:[shoulder] body:[upper_arm_link]
#  [2/20] [None] attached joint:[elbow] body:[upper_forearm_link]
#  [3/20] [None] attached joint:[forearm_roll] body:[lower_forearm_link]
#  [4/20] [None] attached joint:[wrist_angle] body:[wrist_link]
#  [5/20] [None] attached joint:[wrist_rotate] body:[gripper_link]
#  [6/20] [None] attached joint:[left_finger] body:[left_finger_link]
#  [7/20] [None] attached joint:[right_finger] body:[right_finger_link]
#  [8/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [9/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [10/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [11/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [12/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [13/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [14/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [15/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [16/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [17/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [18/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [19/20] [None] attached joint:[None] body:[body_obj_plate_11]
#
# Free joint information. n_free_joint:[2]
#  [0/2] [None] body_name_attached:[body_obj_mug_5]
#  [1/2] [None] body_name_attached:[body_obj_plate_11]
#
# Revolute joint information. n_rev_joint:[6]
#  [0/6] [waist] range:[-3.142]~[3.142]
#  [1/6] [shoulder] range:[-1.850]~[1.257]
#  [2/6] [elbow] range:[-1.763]~[1.606]
#  [3/6] [forearm_roll] range:[-3.142]~[3.142]
#  [4/6] [wrist_angle] range:[-1.867]~[2.234]
#  [5/6] [wrist_rotate] range:[-3.142]~[3.142]
#
# Prismatic joint information. n_pri_joint:[2]
#  [0/2] [left_finger] range:[0.021]~[0.057]
#  [1/2] [right_finger] range:[-0.057]~[-0.021]
#
# Control information. n_ctrl:[7]
#  [0/7] [waist] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [1/7] [shoulder] range:[-1.850]~[1.257] gear:[1.00] type:[JOINT]
#  [2/7] [elbow] range:[-1.763]~[1.606] gear:[1.00] type:[JOINT]
#  [3/7] [forearm_roll] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [4/7] [wrist_angle] range:[-1.867]~[2.234] gear:[1.00] type:[JOINT]
#  [5/7] [wrist_rotate] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [6/7] [gripper] range:[0.021]~[0.057] gear:[1.00] type:[JOINT]
#
# Camera information. n_cam:[3]
#  [0/3] [agentview] fov:[45.0]
#  [1/3] [sideview] fov:[45.0]
#  [2/3] [egocentric] fov:[45.0]
#
# n_sensor:[0]
# sensor_names:[]
# n_site:[7]
# site_names:['pinch', 'bottom_site_mug_5', 'top_site_mug_5', 'horizontal_radius_site_mug_5', 'bottom_site_plate_11', 'top_site_plate_11', 'horizontal_radius_site_plate_11']
# -----------------------------------------------------------------------------
# env:[Tabletop] reset
# env:[Tabletop] reset
# env:[Tabletop] initalize viewer

# %%
while PnPEnv.env.is_viewer_alive():
    PnPEnv.step_env()
    if PnPEnv.env.loop_every(HZ=50):

        # Teleoperate robot
        action, reset  = PnPEnv.teleop_robot()
        if reset:
            PnPEnv.reset(seed=0)

        # Get the end-effector pose 
        ee_pose = PnPEnv.get_ee_pose()
        px, py, pz, roll, pitch, yaw = ee_pose
        
        # radian to degree
        r_deg, p_deg, y_deg = np.rad2deg([roll, pitch, yaw])

        print("-" * 50)
        print(f"ROBOT POSE (EE)")
        print(f"Translation (m)  ->  X: {px:6.3f} | Y: {py:6.3f} | Z: {pz:6.3f}")
        print(f"Orientation (deg) -> Roll: {int(r_deg):3d}° | Pitch: {int(p_deg):3d}° | Yaw: {int(y_deg):3d}°")
        print("-" * 50)

        agent_image,wrist_image = PnPEnv.grab_image()

        # # resize to 256x256
        agent_image = Image.fromarray(agent_image)
        wrist_image = Image.fromarray(wrist_image)

        agent_image = agent_image.resize((256, 256))
        wrist_image = wrist_image.resize((256, 256))

        agent_image = np.array(agent_image)
        wrist_image = np.array(wrist_image)

        joint_q = PnPEnv.step(action)

        PnPEnv.render(teleop=True)

PnPEnv.env.close_viewer()
# Out:
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.357 | Y:  0.000 | Z:  0.436
# Orientation (deg) -> Roll: -179° | Pitch:  88° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.359 | Y: -0.000 | Z:  0.434
# Orientation (deg) -> Roll: -179° | Pitch:  87° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.360 | Y: -0.000 | Z:  0.432
# Orientation (deg) -> Roll: -179° | Pitch:  87° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.362 | Y: -0.000 | Z:  0.430
# Orientation (deg) -> Roll: -179° | Pitch:  87° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.363 | Y: -0.000 | Z:  0.429
# Orientation (deg) -> Roll: -179° | Pitch:  87° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.428
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.427
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: 179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: 178° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: 176° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: 175° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: 174° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: 173° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: 172° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.426
# Orientation (deg) -> Roll: 172° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.426
# Orientation (deg) -> Roll: 171° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.426
# Orientation (deg) -> Roll: 172° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.426
# Orientation (deg) -> Roll: 173° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.426
# Orientation (deg) -> Roll: 175° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.426
# Orientation (deg) -> Roll: 177° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.426
# Orientation (deg) -> Roll: 178° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.425
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.425
# Orientation (deg) -> Roll: -178° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -178° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -177° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -176° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -176° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -175° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -175° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -175° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -174° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -174° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -174° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -174° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -178° | Pitch:  86° | Yaw: 176°
# --------------------------------------------------

# %% [markdown]
# ---------------

# %% [markdown]
# ### 2. Odometry Analysis

# %%
import numpy as np
from PIL import Image
from mujoco_env.y_env import SimpleEnv

xml_path = './asset/trossen_vx300s/scene.xml'
PnPEnv = SimpleEnv(xml_path, seed = 0, state_type = 'joint_angle')
new_plate_pos = np.array([10.5, 0.2, 0.0])
new_mug_pos = np.array([0.5, -0.0, 0.05]) 
PnPEnv.set_obj_pose(p_mug=new_mug_pos, p_plate=new_plate_pos)

action = np.zeros(7)
# Out:
# -----------------------------------------------------------------------------
# name:[Tabletop] dt:[0.002] HZ:[500]
#  n_qpos:[22] n_qvel:[20] n_qacc:[20] n_ctrl:[7]
#  integrator:[EULER]
#
# n_body:[16]
#  [0/16] [world] mass:[0.00]kg
#  [1/16] [base_link] mass:[0.97]kg
#  [2/16] [shoulder_link] mass:[0.80]kg
#  [3/16] [upper_arm_link] mass:[0.79]kg
#  [4/16] [upper_forearm_link] mass:[0.32]kg
#  [5/16] [lower_forearm_link] mass:[0.41]kg
#  [6/16] [wrist_link] mass:[0.12]kg
#  [7/16] [gripper_link] mass:[0.25]kg
#  [8/16] [gripper_prop_link] mass:[0.01]kg
#  [9/16] [left_finger_link] mass:[0.03]kg
#  [10/16] [right_finger_link] mass:[0.03]kg
#  [11/16] [ego_cam_body] mass:[0.00]kg
#  [12/16] [body_obj_mug_5] mass:[0.00]kg
#  [13/16] [object_mug_5] mass:[0.08]kg
#  [14/16] [body_obj_plate_11] mass:[0.00]kg
#  [15/16] [object_plate_11] mass:[0.10]kg
# body_total_mass:[3.93]kg
#
# n_geom:[105]
# geom_names:['floor', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'left_finger_pad_0', 'left_finger_pad_1', 'left_finger_pad_2', 'left_finger_pad_3', 'left_finger_pad_4', 'left_finger_pad_5', 'left_finger_pad_6', 'left_finger_pad_7', 'left_finger_pad_8', None, 'right_finger_pad_0', 'right_finger_pad_1', 'right_finger_pad_2', 'right_finger_pad_3', 'right_finger_pad_4', 'right_finger_pad_5', 'right_finger_pad_6', 'right_finger_pad_7', 'right_finger_pad_8', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# n_mesh:[76]
# mesh_names:['vx300s_1_base', 'vx300s_2_shoulder', 'vx300s_3_upper_arm', 'vx300s_4_upper_forearm', 'vx300s_5_lower_forearm', 'vx300s_6_wrist', 'vx300s_7_gripper', 'vx300s_8_gripper_prop', 'vx300s_9_gripper_bar', 'vx300s_10_gripper_finger', 'mug_5_normalized_0_vis', 'mug_5_normalized_collision_22._coll', 'mug_5_normalized_collision_23._coll', 'mug_5_normalized_collision_21._coll', 'mug_5_normalized_collision_20._coll', 'mug_5_normalized_collision_24._coll', 'mug_5_normalized_collision_30._coll', 'mug_5_normalized_collision_18._coll', 'mug_5_normalized_collision_19._coll', 'mug_5_normalized_collision_31._coll', 'mug_5_normalized_collision_25._coll', 'mug_5_normalized_collision_27._coll', 'mug_5_normalized_collision_26._coll', 'mug_5_normalized_collision_9._coll', 'mug_5_normalized_collision_8._coll', 'mug_5_normalized_collision_6._coll', 'mug_5_normalized_collision_7._coll', 'mug_5_normalized_collision_5._coll', 'mug_5_normalized_collision_4._coll', 'mug_5_normalized_collision_0._coll', 'mug_5_normalized_collision_1._coll', 'mug_5_normalized_collision_3._coll', 'mug_5_normalized_collision_2._coll', 'mug_5_normalized_collision_17._coll', 'mug_5_normalized_collision_16._coll', 'mug_5_normalized_collision_28._coll', 'mug_5_normalized_collision_14._coll', 'mug_5_normalized_collision_15._coll', 'mug_5_normalized_collision_29._coll', 'mug_5_normalized_collision_11._coll', 'mug_5_normalized_collision_10._coll', 'mug_5_normalized_collision_12._coll', 'mug_5_normalized_collision_13._coll', 'plate_11_normalized_0_vis', 'plate_11_normalized_collision_22._coll', 'plate_11_normalized_collision_23._coll', 'plate_11_normalized_collision_21._coll', 'plate_11_normalized_collision_20._coll', 'plate_11_normalized_collision_24._coll', 'plate_11_normalized_collision_30._coll', 'plate_11_normalized_collision_18._coll', 'plate_11_normalized_collision_19._coll', 'plate_11_normalized_collision_31._coll', 'plate_11_normalized_collision_25._coll', 'plate_11_normalized_collision_27._coll', 'plate_11_normalized_collision_26._coll', 'plate_11_normalized_collision_9._coll', 'plate_11_normalized_collision_8._coll', 'plate_11_normalized_collision_6._coll', 'plate_11_normalized_collision_7._coll', 'plate_11_normalized_collision_5._coll', 'plate_11_normalized_collision_4._coll', 'plate_11_normalized_collision_0._coll', 'plate_11_normalized_collision_1._coll', 'plate_11_normalized_collision_3._coll', 'plate_11_normalized_collision_2._coll', 'plate_11_normalized_collision_17._coll', 'plate_11_normalized_collision_16._coll', 'plate_11_normalized_collision_28._coll', 'plate_11_normalized_collision_14._coll', 'plate_11_normalized_collision_15._coll', 'plate_11_normalized_collision_29._coll', 'plate_11_normalized_collision_11._coll', 'plate_11_normalized_collision_10._coll', 'plate_11_normalized_collision_12._coll', 'plate_11_normalized_collision_13._coll']
#
# n_joint:[10]
#  [0/10] [waist] axis:[0. 0. 1.]
#  [1/10] [shoulder] axis:[0. 1. 0.]
#  [2/10] [elbow] axis:[0. 1. 0.]
#  [3/10] [forearm_roll] axis:[1. 0. 0.]
#  [4/10] [wrist_angle] axis:[0. 1. 0.]
#  [5/10] [wrist_rotate] axis:[1. 0. 0.]
#  [6/10] [left_finger] axis:[0. 1. 0.]
#  [7/10] [right_finger] axis:[0. 1. 0.]
#  [8/10] [None] axis:[0. 0. 1.]
#  [9/10] [None] axis:[0. 0. 1.]
#
# n_dof:[20] (=number of rows of Jacobian)
#  [0/20] [None] attached joint:[waist] body:[shoulder_link]
#  [1/20] [None] attached joint:[shoulder] body:[upper_arm_link]
#  [2/20] [None] attached joint:[elbow] body:[upper_forearm_link]
#  [3/20] [None] attached joint:[forearm_roll] body:[lower_forearm_link]
#  [4/20] [None] attached joint:[wrist_angle] body:[wrist_link]
#  [5/20] [None] attached joint:[wrist_rotate] body:[gripper_link]
#  [6/20] [None] attached joint:[left_finger] body:[left_finger_link]
#  [7/20] [None] attached joint:[right_finger] body:[right_finger_link]
#  [8/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [9/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [10/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [11/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [12/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [13/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [14/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [15/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [16/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [17/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [18/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [19/20] [None] attached joint:[None] body:[body_obj_plate_11]
#
# Free joint information. n_free_joint:[2]
#  [0/2] [None] body_name_attached:[body_obj_mug_5]
#  [1/2] [None] body_name_attached:[body_obj_plate_11]
#
# Revolute joint information. n_rev_joint:[6]
#  [0/6] [waist] range:[-3.142]~[3.142]
#  [1/6] [shoulder] range:[-1.850]~[1.257]
#  [2/6] [elbow] range:[-1.763]~[1.606]
#  [3/6] [forearm_roll] range:[-3.142]~[3.142]
#  [4/6] [wrist_angle] range:[-1.867]~[2.234]
#  [5/6] [wrist_rotate] range:[-3.142]~[3.142]
#
# Prismatic joint information. n_pri_joint:[2]
#  [0/2] [left_finger] range:[0.021]~[0.057]
#  [1/2] [right_finger] range:[-0.057]~[-0.021]
#
# Control information. n_ctrl:[7]
#  [0/7] [waist] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [1/7] [shoulder] range:[-1.850]~[1.257] gear:[1.00] type:[JOINT]
#  [2/7] [elbow] range:[-1.763]~[1.606] gear:[1.00] type:[JOINT]
#  [3/7] [forearm_roll] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [4/7] [wrist_angle] range:[-1.867]~[2.234] gear:[1.00] type:[JOINT]
#  [5/7] [wrist_rotate] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [6/7] [gripper] range:[0.021]~[0.057] gear:[1.00] type:[JOINT]
#
# Camera information. n_cam:[3]
#  [0/3] [agentview] fov:[45.0]
#  [1/3] [sideview] fov:[45.0]
#  [2/3] [egocentric] fov:[45.0]
#
# n_sensor:[0]
# sensor_names:[]
# n_site:[7]
# site_names:['pinch', 'bottom_site_mug_5', 'top_site_mug_5', 'horizontal_radius_site_mug_5', 'bottom_site_plate_11', 'top_site_plate_11', 'horizontal_radius_site_plate_11']
# -----------------------------------------------------------------------------
# env:[Tabletop] reset
# env:[Tabletop] reset
# env:[Tabletop] initalize viewer

# %%
target_angle = 45 # degree, press -> key to triggger sim

target_x = 0.05 #cm, press 'w-s' key to triggger sim
target_y = 0.05 #cm, press 'a-d' key to triggger sim
target_z = 0.05 #cm, press 'r-f' key to triggger sim


while PnPEnv.env.is_viewer_alive():
    PnPEnv.step_env()
    if PnPEnv.env.loop_every(HZ=20):

        # teleoperate the robot 
        action, reset  = PnPEnv.test_teleop_robot(w_roll=target_angle, w_pitch = target_angle, w_yaw=target_angle ,w_x=target_x, w_y=target_y, w_z=target_z)
        if reset:
            PnPEnv.reset(seed=0)

        # get the end-effector pose 
        ee_pose = PnPEnv.get_ee_pose()
        px, py, pz, roll, pitch, yaw = ee_pose
        
        # radian to degree
        r_deg, p_deg, y_deg = np.rad2deg([roll, pitch, yaw])

        print("-" * 50)
        print(f"ROBOT POSE (EE)")
        print(f"Translation (m)  ->  X: {px:6.3f} | Y: {py:6.3f} | Z: {pz:6.3f}")
        print(f"Orientation (deg) -> Roll: {int(r_deg):3d}° | Pitch: {int(p_deg):3d}° | Yaw: {int(y_deg):3d}°")
        print("-" * 50)

        agent_image,wrist_image = PnPEnv.grab_image()

        # # resize to 256x256
        agent_image = Image.fromarray(agent_image)
        wrist_image = Image.fromarray(wrist_image)

        agent_image = agent_image.resize((256, 256))
        wrist_image = wrist_image.resize((256, 256))

        agent_image = np.array(agent_image)
        wrist_image = np.array(wrist_image)

        joint_q = PnPEnv.step(action)

        PnPEnv.render(teleop=True)

PnPEnv.env.close_viewer()
# Out:
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.357 | Y:  0.000 | Z:  0.436
# Orientation (deg) -> Roll: -179° | Pitch:  88° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.361 | Y: -0.000 | Z:  0.431
# Orientation (deg) -> Roll: -179° | Pitch:  87° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.428
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.365 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.426
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -179° | Pitch:  86° | Yaw: -179°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: 166° | Pitch:  86° | Yaw: 165°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.425
# Orientation (deg) -> Roll: 164° | Pitch:  86° | Yaw: 164°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.425
# Orientation (deg) -> Roll: -173° | Pitch:  86° | Yaw: -173°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: -167° | Pitch:  86° | Yaw: -167°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: 173° | Pitch:  86° | Yaw: 173°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.425
# Orientation (deg) -> Roll: 167° | Pitch:  86° | Yaw: 167°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y:  0.000 | Z:  0.425
# Orientation (deg) -> Roll: -172° | Pitch:  86° | Yaw: -172°
# --------------------------------------------------
# --------------------------------------------------
# ROBOT POSE (EE)
# Translation (m)  ->  X:  0.364 | Y: -0.000 | Z:  0.424
# Orientation (deg) -> Roll: -166° | Pitch:  86° | Yaw: -166°
# --------------------------------------------------

# %% [markdown]
# ---------------

# %% [markdown]
# ### 3. Visual Odometry Test

# %% [markdown]
# #### 3.1 Library

# %%
import cv2
import numpy as np
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %% [markdown]
# #### 3.2 Filter & Configs

# %%
# filter class 
class EMAFilter:
    def __init__(self, alpha=0.3):
        self.alpha = alpha
        self.state = None

    def apply(self, value):
        if self.state is None:
            self.state = value
        else:
            self.state = self.alpha * value + (1 - self.alpha) * self.state
        return self.state

# orientation filter
filter_x = EMAFilter(alpha=0.2)
filter_y = EMAFilter(alpha=0.2)
filter_z = EMAFilter(alpha=0.2)

# normal vector filter
filter_norm = [EMAFilter(alpha=0.1) for _ in range(3)]

# traslation filter
filter_pos_x = EMAFilter(alpha=0.15)
filter_pos_y = EMAFilter(alpha=0.15)
filter_pos_z = EMAFilter(alpha=0.1) 

# homing
reference_pos = None

# mediapipe configs
mp_hands = mp.tasks.vision.HandLandmarksConnections
mp_drawing = mp.tasks.vision.drawing_utils
mp_drawing_styles = mp.tasks.vision.drawing_styles

MARGIN = 10  
FONT_SIZE = 1
FONT_THICKNESS = 1  
HANDEDNESS_TEXT_COLOR = (88, 205, 54)

base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
options = vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
detector = vision.HandLandmarker.create_from_options(options)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1770222641.589536  645238 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1770222641.611573  645238 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# #### 3.3 Visualization Func

# %%
# position
last_stable_pos = [0.0, 0.0, 0.0] 

def draw_landmarks_on_image(rgb_image, detection_result, prev_angles=None):
    global last_stable_pos
    annotated_image = np.copy(rgb_image)
    
    height, width, _ = annotated_image.shape
    gripper_state = False

    camera_distance_m = 0.0
    palm_normal = np.array([0.0, 0.0, -1.0])
    current_angles = [0.0, 0.0, 0.0]
    angle_deltas = [0.0, 0.0, 0.0]

    final_x, final_y, final_z = last_stable_pos
    
    KNOWN_WIDTH_CM = 2.0
    FOCAL_LENGTH = 400.0 

    if not detection_result.hand_landmarks:
        return annotated_image, gripper_state, tuple(last_stable_pos), palm_normal, current_angles

    for idx, (hand_landmarks, world_landmarks) in enumerate(
            zip(detection_result.hand_landmarks, detection_result.hand_world_landmarks)):

        # depth Calculation 
        p0_px = (int(hand_landmarks[0].x * width), int(hand_landmarks[0].y * height))
        p9_px = (int(hand_landmarks[9].x * width), int(hand_landmarks[9].y * height))
        palm_center_px = ((p0_px[0] + p9_px[0]) // 2, (p0_px[1] + p9_px[1]) // 2)

        p19_px = np.array([hand_landmarks[19].x * width, hand_landmarks[19].y * height])
        p20_px = np.array([hand_landmarks[20].x * width, hand_landmarks[20].y * height])
        pixel_dist = np.linalg.norm(p19_px - p20_px)
        
        if pixel_dist > 0:
            camera_distance_m = (KNOWN_WIDTH_CM * FOCAL_LENGTH) / pixel_dist / 100.0
        
        raw_dist_cm = camera_distance_m * 100.0
        raw_x_cm = ((palm_center_px[0] - width / 2) * raw_dist_cm) / FOCAL_LENGTH
        raw_y_cm = ((palm_center_px[1] - height / 2) * raw_dist_cm) / FOCAL_LENGTH

        # filtering
        smooth_x = filter_pos_x.apply(raw_x_cm)
        smooth_y = filter_pos_y.apply(raw_y_cm)
        smooth_z = filter_pos_z.apply(raw_dist_cm)

        # filtering
        THRESHOLD = 0.4 
        
        final_x = smooth_x if abs(smooth_x - last_stable_pos[0]) > THRESHOLD else last_stable_pos[0]
        final_y = smooth_y if abs(smooth_y - last_stable_pos[1]) > THRESHOLD else last_stable_pos[1]
        final_z = smooth_z if abs(smooth_z - last_stable_pos[2]) > THRESHOLD else last_stable_pos[2]
        
        last_stable_pos = [final_x, final_y, final_z]

        # palm normal
        p0_w = np.array([world_landmarks[0].x, world_landmarks[0].y, world_landmarks[0].z])
        p5_w = np.array([world_landmarks[5].x, world_landmarks[5].y, world_landmarks[5].z])
        p17_w = np.array([world_landmarks[17].x, world_landmarks[17].y, world_landmarks[17].z])
        
        v1, v2 = p5_w - p0_w, p17_w - p0_w
        raw_normal = np.cross(v2, v1)
        if np.linalg.norm(raw_normal) > 0:
            raw_normal /= np.linalg.norm(raw_normal)
        
        # palm normal filtering
        palm_normal = np.array([
            filter_norm[0].apply(raw_normal[0]),
            filter_norm[1].apply(raw_normal[1]),
            filter_norm[2].apply(raw_normal[2])
        ])
        palm_normal /= np.linalg.norm(palm_normal)

        # degree filtering
        raw_angles = [
            np.degrees(np.arccos(np.clip(palm_normal[0], -1.0, 1.0))),
            np.degrees(np.arccos(np.clip(palm_normal[1], -1.0, 1.0))),
            np.degrees(np.arccos(np.clip(palm_normal[2], -1.0, 1.0)))
        ]
        current_angles = [
            filter_x.apply(raw_angles[0]),
            filter_y.apply(raw_angles[1]),
            filter_z.apply(raw_angles[2])
        ]

        if prev_angles is not None:
            angle_deltas = [current_angles[i] - prev_angles[i] for i in range(3)]

        # gripper orientation
        abs_vals = [abs(x) for x in palm_normal]
        max_idx = abs_vals.index(max(abs_vals))
        directions = [("left" if palm_normal[0]>0 else "right"), 
                      ("down" if palm_normal[1]>0 else "up"), 
                      ("in" if palm_normal[2]>0 else "out")]
        dir_text = directions[max_idx]

        p4_w = np.array([world_landmarks[4].x, world_landmarks[4].y, world_landmarks[4].z])
        dist_gripper = np.linalg.norm(p4_w - np.array([world_landmarks[8].x, world_landmarks[8].y, world_landmarks[8].z])) * 100
        
        line_color = (0, 255, 0) 
        if dist_gripper < 8.0: 
            gripper_state = True
            line_color = (255, 0, 0) 


        p4_px = (int(hand_landmarks[4].x * width), int(hand_landmarks[4].y * height))
        p8_px = (int(hand_landmarks[8].x * width), int(hand_landmarks[8].y * height))        
        cv2.line(annotated_image, p4_px, p8_px, line_color, 2)

        # info panel
        overlay = annotated_image.copy()
        cv2.rectangle(overlay, (10, 10), (260, 480), (0, 0, 0), -1)
        cv2.addWeighted(overlay, 0.7, annotated_image, 0.3, 0, annotated_image)

        c_white, c_yellow, c_magenta = (255, 255, 255), (0, 255, 255), (255, 0, 255)
        cv2.putText(annotated_image, f"Orientation (degree) - {dir_text}", (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (150, 150, 150), 1)
        
        for i, ax in enumerate(["X", "Y", "Z"]):
            y_pos = 80 + (i * 30)
            d_color = (0, 0, 255) if angle_deltas[i] > 0.5 else (0, 255, 0) if angle_deltas[i] < -0.5 else c_white
            cv2.putText(annotated_image, f"{ax} Degree: {int(current_angles[i])} deg", (20, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 0.5, c_yellow, 1)

        cv2.putText(annotated_image, "Translation (cm)", (20, 220), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (150, 150, 150), 1)
        cv2.putText(annotated_image, f"X (Right-Left): {final_x:>5.1f} cm", (20, 250), cv2.FONT_HERSHEY_SIMPLEX, 0.5, c_yellow, 1)
        cv2.putText(annotated_image, f"Y (Up-Down): {final_y:>5.1f} cm", (20, 280), cv2.FONT_HERSHEY_SIMPLEX, 0.5, c_yellow, 1)
        cv2.putText(annotated_image, f"Z (Depth): {final_z:>5.1f} cm", (20, 310), cv2.FONT_HERSHEY_SIMPLEX, 0.5, c_yellow, 1)

        status_text = "GRIPPER: Close" if gripper_state else "GRIPPER: Open"
        cv2.putText(annotated_image, status_text, (20, 450), cv2.FONT_HERSHEY_SIMPLEX, 0.8, line_color if gripper_state else line_color, 2)

        cv2.circle(annotated_image, palm_center_px, 7, c_magenta, -1)
        cv2.arrowedLine(annotated_image, palm_center_px, 
                        (int(palm_center_px[0] + palm_normal[0]*90), 
                        int(palm_center_px[1] + palm_normal[1]*90)), 
                c_white, 3)

    mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    return annotated_image, gripper_state, (final_x, final_y, final_z), palm_normal, current_angles

# %% [markdown]
# Extracted main infos with this func:
# - Coordinates and orientation of hand center to move the ee
# - Distance between fingers joints to be able close and open the gripper

# %% [markdown]
# #### 3.4 Main Loop

# %%
# Using IP camera with OpenCV
"""
import cv2

cap = cv2.VideoCapture("http://192.168.1.9:8080/video")
address = "https://192.168.1.6:8080/video"
cap.open(address)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imshow("iPhone Camera", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
"""

# %%
# using ip camera
cap = cv2.VideoCapture("http://192.168.1.6:8080/video")
address = "https://192.168.1.6:8080/video"
cap.open(address)

while True:
    ret, frame = cap.read()
    if not ret: break

    frame = cv2.flip(frame, 1)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
    detection_result = detector.detect(mp_image)
    
    annotated_frame, state_, coords, palm_normal, current_angles = draw_landmarks_on_image(rgb_frame, detection_result)
    
    # print("[INFO] Palm XYZ: ", coords)
    cv2.imshow('Hand Orientation', cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR))

    if cv2.waitKey(1) & 0xFF == ord('q'): break

cap.release()
cv2.destroyAllWindows()

# %%
# using PC webcam
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret: break

    frame = cv2.flip(frame, 1)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
    detection_result = detector.detect(mp_image)
    
    annotated_frame, state_, coords, palm_normal, current_angles = draw_landmarks_on_image(rgb_frame, detection_result)
    
    # print("[INFO] Palm XYZ: ", coords)
    cv2.imshow('Hand Orientation', cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR))

    if cv2.waitKey(1) & 0xFF == ord('q'): break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 5. System Integration Test

# %% [markdown]
# This part is about (Viperx300s) end effector movement tests based on hand odometry which taken from IP Camera

# %%
import numpy as np
from PIL import Image
from mujoco_env.y_env import SimpleEnv

import cv2
import numpy as np
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

import threading
import time

# %%
class EMAFilter:
    def __init__(self, alpha=0.3):
        self.alpha = alpha
        self.state = None
    def apply(self, value):
        if self.state is None: self.state = value
        else: self.state = self.alpha * value + (1 - self.alpha) * self.state
        return self.state

filter_x = EMAFilter(alpha=0.2)
filter_y = EMAFilter(alpha=0.2)
filter_z = EMAFilter(alpha=0.2)
filter_norm = [EMAFilter(alpha=0.1) for _ in range(3)]
filter_pos_x = EMAFilter(alpha=0.15)
filter_pos_y = EMAFilter(alpha=0.15)
filter_pos_z = EMAFilter(alpha=0.1)

ref_pos = None   # [x, y, z] cm
ref_angles = None # [roll, pitch, yaw] deg
last_stable_pos = [0.0, 0.0, 0.0]
prev_palm_center = None
alpha_p = 0.3  
threshold_p = 10

reference_pos = None

mp_hands = mp.tasks.vision.HandLandmarksConnections
mp_drawing = mp.tasks.vision.drawing_utils
mp_drawing_styles = mp.tasks.vision.drawing_styles

MARGIN = 10  
FONT_SIZE = 1
FONT_THICKNESS = 1  
HANDEDNESS_TEXT_COLOR = (88, 205, 54)

base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
options = vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
detector = vision.HandLandmarker.create_from_options(options)

gripper_state_ = False
final_rel_angles = [0.0, 0.0, 0.0]
action = np.zeros(7)
delta_ = [0, 0]
camera_distance_m_ = 0.0
coords_ = (0.0, 0.0, 0.0)

# %%
# GLOBALS
last_stable_pos = [0.0, 0.0, 0.0]
ref_pos = None
ref_angles = None

def draw_landmarks_on_image(rgb_image, detection_result):
    global last_stable_pos, ref_pos, ref_angles

    annotated_image = np.copy(rgb_image)
    height, width, _ = annotated_image.shape

    gripper_state = False
    palm_normal = np.array([0.0, 0.0, -1.0])
    current_angles = [0.0, 0.0, 0.0]

    final_x, final_y, final_z = last_stable_pos
    final_rel_pos = (0.0, 0.0, 0.0)
    final_rel_angles = [0.0, 0.0, 0.0]

    KNOWN_WIDTH_CM = 2.0
    FOCAL_LENGTH = 400.0

    if not detection_result.hand_landmarks:
        ref_pos = None
        ref_angles = None
        return annotated_image, gripper_state, final_rel_angles, final_rel_pos, "None"

    for hand_landmarks, world_landmarks in zip(
        detection_result.hand_landmarks,
        detection_result.hand_world_landmarks
    ):

        p19_px = np.array([hand_landmarks[19].x * width, hand_landmarks[19].y * height])
        p20_px = np.array([hand_landmarks[20].x * width, hand_landmarks[20].y * height])
        pixel_dist = np.linalg.norm(p19_px - p20_px)

        camera_distance_m = (KNOWN_WIDTH_CM * FOCAL_LENGTH) / pixel_dist / 100.0 if pixel_dist > 0 else 0.0
        raw_dist_cm = camera_distance_m * 100.0

        p0_px = (int(hand_landmarks[0].x * width), int(hand_landmarks[0].y * height))
        p9_px = (int(hand_landmarks[9].x * width), int(hand_landmarks[9].y * height))
        palm_center_px = ((p0_px[0] + p9_px[0]) // 2, (p0_px[1] + p9_px[1]) // 2)

        raw_x_cm = ((palm_center_px[0] - width / 2) * raw_dist_cm) / FOCAL_LENGTH
        raw_y_cm = ((palm_center_px[1] - height / 2) * raw_dist_cm) / FOCAL_LENGTH

        # 
        smooth_x = filter_pos_x.apply(raw_x_cm)
        smooth_y = filter_pos_y.apply(raw_y_cm)
        smooth_z = filter_pos_z.apply(raw_dist_cm)

        THR = 0.4
        final_x = smooth_x if abs(smooth_x - last_stable_pos[0]) > THR else last_stable_pos[0]
        final_y = smooth_y if abs(smooth_y - last_stable_pos[1]) > THR else last_stable_pos[1]
        final_z = smooth_z if abs(smooth_z - last_stable_pos[2]) > THR else last_stable_pos[2]

        last_stable_pos = [final_x, final_y, final_z]

        p0_w = np.array([world_landmarks[0].x, world_landmarks[0].y, world_landmarks[0].z])
        p5_w = np.array([world_landmarks[5].x, world_landmarks[5].y, world_landmarks[5].z])
        p17_w = np.array([world_landmarks[17].x, world_landmarks[17].y, world_landmarks[17].z])

        raw_normal = np.cross(p17_w - p0_w, p5_w - p0_w)
        if np.linalg.norm(raw_normal) > 1e-6:
            raw_normal /= np.linalg.norm(raw_normal)

        palm_normal = np.array([filter_norm[i].apply(raw_normal[i]) for i in range(3)])
        palm_normal /= np.linalg.norm(palm_normal)

        raw_angles = [
            np.degrees(np.arccos(np.clip(palm_normal[i], -1.0, 1.0)))
            for i in range(3)
        ]

        current_angles = [
            filter_x.apply(raw_angles[0]),
            filter_y.apply(raw_angles[1]),
            filter_z.apply(raw_angles[2])
        ]

        if ref_angles is None:
            ref_angles = current_angles.copy()

        final_rel_angles = [
            current_angles[i] - ref_angles[i] for i in range(3)
        ]

        p4_w = np.array([world_landmarks[4].x, world_landmarks[4].y, world_landmarks[4].z])
        p8_w = np.array([world_landmarks[8].x, world_landmarks[8].y, world_landmarks[8].z])
        dist_gripper = np.linalg.norm(p4_w - p8_w) * 100

        line_color = (0, 255, 0)
        if dist_gripper < 6.0:
            gripper_state = True
            line_color = (0, 0, 255)

        p4_px = (int(hand_landmarks[4].x * width), int(hand_landmarks[4].y * height))
        p8_px = (int(hand_landmarks[8].x * width), int(hand_landmarks[8].y * height))
        cv2.line(annotated_image, p4_px, p8_px, line_color, 2)

        overlay = annotated_image.copy()
        cv2.rectangle(overlay, (10, 10), (260, 480), (0, 0, 0), -1)
        cv2.addWeighted(overlay, 0.7, annotated_image, 0.3, 0, annotated_image)

        c_white = (255, 255, 255)
        c_yellow = (0, 255, 255)
        c_magenta = (255, 0, 255)

        abs_vals = [abs(x) for x in palm_normal]
        max_idx = abs_vals.index(max(abs_vals))
        directions = [("left" if palm_normal[0]>0 else "right"), 
                      ("down" if palm_normal[1]>0 else "up"), 
                      ("in" if palm_normal[2]>0 else "out")]
        dir_text = directions[max_idx]

        cv2.putText(
            annotated_image,
            f"Orientation (degree) - {dir_text}",
            (20, 50),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.5,
            (150, 150, 150),
            1
        )

        for i, ax in enumerate(["X", "Y", "Z"]):
            cv2.putText(
                annotated_image,
                f"{ax} Degree: {int(final_rel_angles[i])} deg",
                (20, 80 + i * 30),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                c_yellow,
                1
            )

        cv2.putText(annotated_image, "Translation (cm)", (20, 220),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (150, 150, 150), 1)
        cv2.putText(annotated_image, f"X: {last_stable_pos[0]:5.1f}", (20, 250),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, c_yellow, 1)
        cv2.putText(annotated_image, f"Y: {last_stable_pos[1]:5.1f}", (20, 280),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, c_yellow, 1)
        cv2.putText(annotated_image, f"Z: {last_stable_pos[2]:5.1f}", (20, 310),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, c_yellow, 1)

        cv2.putText(
            annotated_image,
            "GRIPPER: CLOSE" if gripper_state else "GRIPPER: OPEN",
            (20, 450),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.8,
            line_color,
            2
        )

        cv2.circle(annotated_image, palm_center_px, 7, c_magenta, -1)
        cv2.arrowedLine(
            annotated_image,
            palm_center_px,
            (int(palm_center_px[0] + palm_normal[0] * 90),
             int(palm_center_px[1] + palm_normal[1] * 90)),
            c_white,
            3
        )

        mp_drawing.draw_landmarks(
            annotated_image,
            hand_landmarks,
            mp_hands.HAND_CONNECTIONS
        )

    return annotated_image, gripper_state, final_rel_angles, last_stable_pos, dir_text

# %% [markdown]
# #### 5.1 Translation Test

# %%
# using IP Camera

def camera_thread():
    global action, gripper_state_, final_rel_angles, coords_
    cap = cv2.VideoCapture("http://192.168.1.6:8080/video")
    address = "https://192.168.1.6:8080/video"
    cap.open(address)
    # cap = cv2.VideoCapture(0)
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.flip(frame, 1)
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        detection_result = detector.detect(mp_image)
        
        res = draw_landmarks_on_image(rgb_frame, detection_result)
        annotated_frame, state_, final_rel_angles, coords_, _ = res
        gripper_state_ = bool(state_)

        cv2.imshow('Hand Orientation', cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()


def sim_thread():
    global action, coords_, final_rel_angles
    hand_z_cm_= 0
    

    xml_path = './asset/trossen_vx300s/scene.xml'
    PnPEnv = SimpleEnv(xml_path, seed = 0, state_type = 'joint_angle')
    new_plate_pos = np.array([10.5, 0.2, 0.0])
    new_mug_pos = np.array([0.35, -0.0, 0.05]) # Kupa da masada kalsın
    PnPEnv.set_obj_pose(p_mug=new_mug_pos, p_plate=new_plate_pos)

    action = np.zeros(7)    
    reset = False
        
    while PnPEnv.env.is_viewer_alive():
        PnPEnv.step_env()
        if PnPEnv.env.loop_every(HZ=20):
            curr_ee_pose = PnPEnv.get_ee_pose()

            current_gripper = gripper_state_
            hand_x_cm, hand_y_cm, hand_z_cm = coords_
            hand_y_cm = -hand_y_cm
            
            print("[INFO].. ",hand_x_cm, hand_y_cm, hand_z_cm)

            if abs(hand_z_cm) > 70 or hand_z_cm == 0:
                hand_z_cm_ = 0

            if 10 < abs(hand_z_cm) < 60:
                hand_z_cm_ = (60 - hand_z_cm) * 0.8

            # print("[INFO].. ",hand_x_cm, hand_y_cm, hand_z_cm)
            
            wrist_x = -final_rel_angles[0]
            wrist_y = -final_rel_angles[1]
            wrist_z = final_rel_angles[2]

            # print("wrist x: ", wrist_x)
            # print("wrist z: ", wrist_z)
            # action, reset, yaw, error_yaw  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, 
            #                                            w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, 
            #                                            w_x = hand_z_cm_, w_y = hand_x_cm, w_z = hand_y_cm*1.3)
            action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, 
                                                                        w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, 
                                                                        w_x = hand_z_cm_, w_y = 0.0, w_z = 0.0*1.3)

            # print("[INFO]..Target ",yaw, "-", error_yaw)
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=0.0, w_y=0.0, w_z = hand_y_cm)
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=hand_z_cm, w_y=0.0, w_z = 0.0)
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=0.0, w_y=hand_x_cm, w_z = 0.0)


            if reset:
                PnPEnv.reset(seed=0)

            # Get the end-effector pose and images
            ee_pose = PnPEnv.get_ee_pose()

            # İlk 3 eleman pozisyon (x, y, z), son 3 eleman rotasyon (roll, pitch, yaw)
            # px, py, pz, roll, pitch, yaw = ee_pose
            # print(f"Pozisyon: X={px:.2f}, Y={py:.2f}, Z={pz:.2f}")
            # print(f"Rotasyon (Radyan): R={roll:.2f}, P={pitch:.2f}, Y={yaw:.2f}")
                        

            agent_image,wrist_image = PnPEnv.grab_image()

            # resize to 256x256
            agent_image = Image.fromarray(agent_image)
            wrist_image = Image.fromarray(wrist_image)

            agent_image = agent_image.resize((256, 256))
            wrist_image = wrist_image.resize((256, 256))

            agent_image = np.array(agent_image)
            wrist_image = np.array(wrist_image)

            joint_q = PnPEnv.step(action)

            PnPEnv.render(teleop=True)

    PnPEnv.env.close_viewer()

# Start threads
t1 = threading.Thread(target=camera_thread)
t2 = threading.Thread(target=sim_thread)
t1.start()
t2.start()
t1.join()
t2.join()

# %% [markdown]
# #### 5.2 Orientation Test

# %%
# using webcam not a good practice but just for testing
def camera_thread():
    global action, gripper_state_, final_rel_angles, coords_

    cap = cv2.VideoCapture(0)
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.flip(frame, 1)
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        detection_result = detector.detect(mp_image)
        
        res = draw_landmarks_on_image(rgb_frame, detection_result)
        annotated_frame, state_, final_rel_angles, coords_ = res
        gripper_state_ = bool(state_)

        cv2.imshow('Hand Orientation', cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()


def sim_thread():
    global action, coords_, final_rel_angles
    hand_z_cm_= 0
    

    xml_path = './asset/trossen_vx300s/scene.xml'
    PnPEnv = SimpleEnv(xml_path, seed = 0, state_type = 'joint_angle')
    new_plate_pos = np.array([10.5, 0.2, 0.0])
    new_mug_pos = np.array([0.35, -0.0, 0.05]) 
    PnPEnv.set_obj_pose(p_mug=new_mug_pos, p_plate=new_plate_pos)

    action = np.zeros(7)    
    reset = False
        
    while PnPEnv.env.is_viewer_alive():
        PnPEnv.step_env()
        if PnPEnv.env.loop_every(HZ=50):
            curr_ee_pose = PnPEnv.get_ee_pose()

            current_gripper = gripper_state_
            hand_x_cm, hand_y_cm, hand_z_cm = coords_
            hand_y_cm = -hand_y_cm
            
            # print("[INFO].. ",hand_x_cm, hand_y_cm, hand_z_cm)

            if abs(hand_z_cm) > 70 or hand_z_cm == 0:
                hand_z_cm_ = 0

            if 10 < abs(hand_z_cm) < 60:
                hand_z_cm_ = (60 - hand_z_cm) * 0.8

            # print("[INFO].. ",hand_x_cm, hand_y_cm, hand_z_cm)
            
            wrist_x = -final_rel_angles[0]
            wrist_y = -final_rel_angles[1]
            wrist_z = final_rel_angles[2]

            # print("wrist x: ", wrist_x)
            # print("wrist y: ", wrist_y)
            # print("wrist z: ", wrist_z)
            
            action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, 
                                                       w_pitch = wrist_y, w_roll = wrist_x , w_yaw = 0.0, 
                                                       w_x = 0.0, w_y = 0.0, w_z = 0.0)



            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=0.0, w_y=0.0, w_z = hand_y_cm)
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=hand_z_cm, w_y=0.0, w_z = 0.0)
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=0.0, w_y=hand_x_cm, w_z = 0.0)


            if reset:
                PnPEnv.reset(seed=0)

            # Get the end-effector pose and images
            ee_pose = PnPEnv.get_ee_pose()

            px, py, pz, roll, pitch, yaw = ee_pose
            # print(f"Pozisyon: X={px:.2f}, Y={py:.2f}, Z={pz:.2f}")
            print(f"Rotasyon (Radyan): R={roll:.2f}, P={pitch:.2f}, Y={yaw:.2f}")
                        

            agent_image,wrist_image = PnPEnv.grab_image()

            # resize to 256x256
            agent_image = Image.fromarray(agent_image)
            wrist_image = Image.fromarray(wrist_image)

            agent_image = agent_image.resize((256, 256))
            wrist_image = wrist_image.resize((256, 256))

            agent_image = np.array(agent_image)
            wrist_image = np.array(wrist_image)

            joint_q = PnPEnv.step(action)

            PnPEnv.render(teleop=True)

    PnPEnv.env.close_viewer()

# Start threads
t1 = threading.Thread(target=camera_thread)
t2 = threading.Thread(target=sim_thread)
t1.start()
t2.start()
t1.join()
t2.join()
# Out:
# W0000 00:00:1770213450.247913  626413 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QFontDatabase: Cannot find font directory /home/oguz/miniconda3/envs/lerobot_env/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/oguz/miniconda3/envs/lerobot_env/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/oguz/miniconda3/envs/lerobot_env/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/oguz/miniconda3/envs/lerobot_env/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/oguz/miniconda3/envs/lerobot_env/lib/python3.10/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# -----------------------------------------------------------------------------
# name:[Tabletop] dt:[0.002] HZ:[500]
#  n_qpos:[22] n_qvel:[20] n_qacc:[20] n_ctrl:[7]
#  integrator:[EULER]
#
# n_body:[16]
#  [0/16] [world] mass:[0.00]kg
#  [1/16] [base_link] mass:[0.97]kg
#  [2/16] [shoulder_link] mass:[0.80]kg
#  [3/16] [upper_arm_link] mass:[0.79]kg
#  [4/16] [upper_forearm_link] mass:[0.32]kg
#  [5/16] [lower_forearm_link] mass:[0.41]kg
#  [6/16] [wrist_link] mass:[0.12]kg
#  [7/16] [gripper_link] mass:[0.25]kg
#  [8/16] [gripper_prop_link] mass:[0.01]kg
#  [9/16] [left_finger_link] mass:[0.03]kg
#  [10/16] [right_finger_link] mass:[0.03]kg
#  [11/16] [ego_cam_body] mass:[0.00]kg
#  [12/16] [body_obj_mug_5] mass:[0.00]kg
#  [13/16] [object_mug_5] mass:[0.08]kg
#  [14/16] [body_obj_plate_11] mass:[0.00]kg
#  [15/16] [object_plate_11] mass:[0.10]kg
# body_total_mass:[3.93]kg
#
# n_geom:[105]
# geom_names:['floor', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'left_finger_pad_0', 'left_finger_pad_1', 'left_finger_pad_2', 'left_finger_pad_3', 'left_finger_pad_4', 'left_finger_pad_5', 'left_finger_pad_6', 'left_finger_pad_7', 'left_finger_pad_8', None, 'right_finger_pad_0', 'right_finger_pad_1', 'right_finger_pad_2', 'right_finger_pad_3', 'right_finger_pad_4', 'right_finger_pad_5', 'right_finger_pad_6', 'right_finger_pad_7', 'right_finger_pad_8', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
#
# n_mesh:[76]
# mesh_names:['vx300s_1_base', 'vx300s_2_shoulder', 'vx300s_3_upper_arm', 'vx300s_4_upper_forearm', 'vx300s_5_lower_forearm', 'vx300s_6_wrist', 'vx300s_7_gripper', 'vx300s_8_gripper_prop', 'vx300s_9_gripper_bar', 'vx300s_10_gripper_finger', 'mug_5_normalized_0_vis', 'mug_5_normalized_collision_22._coll', 'mug_5_normalized_collision_23._coll', 'mug_5_normalized_collision_21._coll', 'mug_5_normalized_collision_20._coll', 'mug_5_normalized_collision_24._coll', 'mug_5_normalized_collision_30._coll', 'mug_5_normalized_collision_18._coll', 'mug_5_normalized_collision_19._coll', 'mug_5_normalized_collision_31._coll', 'mug_5_normalized_collision_25._coll', 'mug_5_normalized_collision_27._coll', 'mug_5_normalized_collision_26._coll', 'mug_5_normalized_collision_9._coll', 'mug_5_normalized_collision_8._coll', 'mug_5_normalized_collision_6._coll', 'mug_5_normalized_collision_7._coll', 'mug_5_normalized_collision_5._coll', 'mug_5_normalized_collision_4._coll', 'mug_5_normalized_collision_0._coll', 'mug_5_normalized_collision_1._coll', 'mug_5_normalized_collision_3._coll', 'mug_5_normalized_collision_2._coll', 'mug_5_normalized_collision_17._coll', 'mug_5_normalized_collision_16._coll', 'mug_5_normalized_collision_28._coll', 'mug_5_normalized_collision_14._coll', 'mug_5_normalized_collision_15._coll', 'mug_5_normalized_collision_29._coll', 'mug_5_normalized_collision_11._coll', 'mug_5_normalized_collision_10._coll', 'mug_5_normalized_collision_12._coll', 'mug_5_normalized_collision_13._coll', 'plate_11_normalized_0_vis', 'plate_11_normalized_collision_22._coll', 'plate_11_normalized_collision_23._coll', 'plate_11_normalized_collision_21._coll', 'plate_11_normalized_collision_20._coll', 'plate_11_normalized_collision_24._coll', 'plate_11_normalized_collision_30._coll', 'plate_11_normalized_collision_18._coll', 'plate_11_normalized_collision_19._coll', 'plate_11_normalized_collision_31._coll', 'plate_11_normalized_collision_25._coll', 'plate_11_normalized_collision_27._coll', 'plate_11_normalized_collision_26._coll', 'plate_11_normalized_collision_9._coll', 'plate_11_normalized_collision_8._coll', 'plate_11_normalized_collision_6._coll', 'plate_11_normalized_collision_7._coll', 'plate_11_normalized_collision_5._coll', 'plate_11_normalized_collision_4._coll', 'plate_11_normalized_collision_0._coll', 'plate_11_normalized_collision_1._coll', 'plate_11_normalized_collision_3._coll', 'plate_11_normalized_collision_2._coll', 'plate_11_normalized_collision_17._coll', 'plate_11_normalized_collision_16._coll', 'plate_11_normalized_collision_28._coll', 'plate_11_normalized_collision_14._coll', 'plate_11_normalized_collision_15._coll', 'plate_11_normalized_collision_29._coll', 'plate_11_normalized_collision_11._coll', 'plate_11_normalized_collision_10._coll', 'plate_11_normalized_collision_12._coll', 'plate_11_normalized_collision_13._coll']
#
# n_joint:[10]
#  [0/10] [waist] axis:[0. 0. 1.]
#  [1/10] [shoulder] axis:[0. 1. 0.]
#  [2/10] [elbow] axis:[0. 1. 0.]
#  [3/10] [forearm_roll] axis:[1. 0. 0.]
#  [4/10] [wrist_angle] axis:[0. 1. 0.]
#  [5/10] [wrist_rotate] axis:[1. 0. 0.]
#  [6/10] [left_finger] axis:[0. 1. 0.]
#  [7/10] [right_finger] axis:[0. 1. 0.]
#  [8/10] [None] axis:[0. 0. 1.]
#  [9/10] [None] axis:[0. 0. 1.]
#
# n_dof:[20] (=number of rows of Jacobian)
#  [0/20] [None] attached joint:[waist] body:[shoulder_link]
#  [1/20] [None] attached joint:[shoulder] body:[upper_arm_link]
#  [2/20] [None] attached joint:[elbow] body:[upper_forearm_link]
#  [3/20] [None] attached joint:[forearm_roll] body:[lower_forearm_link]
#  [4/20] [None] attached joint:[wrist_angle] body:[wrist_link]
#  [5/20] [None] attached joint:[wrist_rotate] body:[gripper_link]
#  [6/20] [None] attached joint:[left_finger] body:[left_finger_link]
#  [7/20] [None] attached joint:[right_finger] body:[right_finger_link]
#  [8/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [9/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [10/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [11/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [12/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [13/20] [None] attached joint:[None] body:[body_obj_mug_5]
#  [14/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [15/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [16/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [17/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [18/20] [None] attached joint:[None] body:[body_obj_plate_11]
#  [19/20] [None] attached joint:[None] body:[body_obj_plate_11]
#
# Free joint information. n_free_joint:[2]
#  [0/2] [None] body_name_attached:[body_obj_mug_5]
#  [1/2] [None] body_name_attached:[body_obj_plate_11]
#
# Revolute joint information. n_rev_joint:[6]
#  [0/6] [waist] range:[-3.142]~[3.142]
#  [1/6] [shoulder] range:[-1.850]~[1.257]
#  [2/6] [elbow] range:[-1.763]~[1.606]
#  [3/6] [forearm_roll] range:[-3.142]~[3.142]
#  [4/6] [wrist_angle] range:[-1.867]~[2.234]
#  [5/6] [wrist_rotate] range:[-3.142]~[3.142]
#
# Prismatic joint information. n_pri_joint:[2]
#  [0/2] [left_finger] range:[0.021]~[0.057]
#  [1/2] [right_finger] range:[-0.057]~[-0.021]
#
# Control information. n_ctrl:[7]
#  [0/7] [waist] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [1/7] [shoulder] range:[-1.850]~[1.257] gear:[1.00] type:[JOINT]
#  [2/7] [elbow] range:[-1.763]~[1.606] gear:[1.00] type:[JOINT]
#  [3/7] [forearm_roll] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [4/7] [wrist_angle] range:[-1.867]~[2.234] gear:[1.00] type:[JOINT]
#  [5/7] [wrist_rotate] range:[-3.142]~[3.142] gear:[1.00] type:[JOINT]
#  [6/7] [gripper] range:[0.021]~[0.057] gear:[1.00] type:[JOINT]
#
# Camera information. n_cam:[3]
#  [0/3] [agentview] fov:[45.0]
#  [1/3] [sideview] fov:[45.0]
#  [2/3] [egocentric] fov:[45.0]
#
# n_sensor:[0]
# sensor_names:[]
# n_site:[7]
# site_names:['pinch', 'bottom_site_mug_5', 'top_site_mug_5', 'horizontal_radius_site_mug_5', 'bottom_site_plate_11', 'top_site_plate_11', 'horizontal_radius_site_plate_11']
# -----------------------------------------------------------------------------
# env:[Tabletop] reset
# env:[Tabletop] reset
# env:[Tabletop] initalize viewer
# Rotasyon (Radyan): R=-0.00, P=0.05, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=0.06, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=0.07, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.08, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.08, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.08, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.08, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.08, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.07, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.06, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.06, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.05, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.04, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.03, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.03, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.02, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.02, Y=-0.00
# Kalibrasyon başladı... Elinizi sabit tutun.
# Rotasyon (Radyan): R=-0.00, P=0.01, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=0.01, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=-0.01, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=-0.03, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=-0.05, Y=-0.00
# Rotasyon (Radyan): R=-0.00, P=-0.08, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.11, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.14, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.18, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.21, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.24, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.28, Y=0.00
# Kalibrasyon tamamlandı! Kontrol aktif.
# Rotasyon (Radyan): R=-0.00, P=-0.31, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.34, Y=0.00
# Rotasyon (Radyan): R=-0.00, P=-0.36, Y=0.00
# Rotasyon (Radyan): R=-0.01, P=-0.38, Y=0.00
# Rotasyon (Radyan): R=-0.02, P=-0.40, Y=0.00
# Rotasyon (Radyan): R=-0.04, P=-0.42, Y=0.00
# Rotasyon (Radyan): R=-0.05, P=-0.44, Y=0.00
# Rotasyon (Radyan): R=-0.06, P=-0.45, Y=0.00
# Rotasyon (Radyan): R=-0.06, P=-0.46, Y=-0.00
# Rotasyon (Radyan): R=-0.07, P=-0.47, Y=-0.00
# Rotasyon (Radyan): R=-0.07, P=-0.47, Y=-0.00
# Rotasyon (Radyan): R=-0.08, P=-0.47, Y=-0.00
# Rotasyon (Radyan): R=-0.08, P=-0.46, Y=-0.01
# Rotasyon (Radyan): R=-0.08, P=-0.46, Y=-0.01
# Rotasyon (Radyan): R=-0.08, P=-0.45, Y=-0.01
# Rotasyon (Radyan): R=-0.08, P=-0.43, Y=-0.01
# Rotasyon (Radyan): R=-0.08, P=-0.42, Y=-0.02
# Rotasyon (Radyan): R=-0.08, P=-0.40, Y=-0.02
# Rotasyon (Radyan): R=-0.08, P=-0.38, Y=-0.02
# Rotasyon (Radyan): R=-0.08, P=-0.36, Y=-0.02
# Rotasyon (Radyan): R=-0.08, P=-0.34, Y=-0.03
# Rotasyon (Radyan): R=-0.08, P=-0.33, Y=-0.03
# Rotasyon (Radyan): R=-0.08, P=-0.31, Y=-0.03
# Rotasyon (Radyan): R=-0.08, P=-0.29, Y=-0.03
# Rotasyon (Radyan): R=-0.07, P=-0.27, Y=-0.04
# Rotasyon (Radyan): R=-0.07, P=-0.26, Y=-0.04
# Rotasyon (Radyan): R=-0.07, P=-0.25, Y=-0.04
# Rotasyon (Radyan): R=-0.07, P=-0.23, Y=-0.03
# Rotasyon (Radyan): R=-0.08, P=-0.22, Y=-0.03
# Rotasyon (Radyan): R=-0.10, P=-0.21, Y=-0.03
# Rotasyon (Radyan): R=-0.12, P=-0.21, Y=-0.03
# Rotasyon (Radyan): R=-0.15, P=-0.20, Y=-0.03
# Rotasyon (Radyan): R=-0.18, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.21, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.23, P=-0.18, Y=-0.02
# Rotasyon (Radyan): R=-0.25, P=-0.18, Y=-0.02
# Rotasyon (Radyan): R=-0.27, P=-0.18, Y=-0.02
# Rotasyon (Radyan): R=-0.28, P=-0.18, Y=-0.02
# Rotasyon (Radyan): R=-0.29, P=-0.18, Y=-0.01
# Rotasyon (Radyan): R=-0.30, P=-0.18, Y=-0.01
# Rotasyon (Radyan): R=-0.31, P=-0.19, Y=-0.01
# Rotasyon (Radyan): R=-0.32, P=-0.19, Y=-0.01
# Rotasyon (Radyan): R=-0.32, P=-0.19, Y=-0.01
# Rotasyon (Radyan): R=-0.33, P=-0.19, Y=-0.01
# Rotasyon (Radyan): R=-0.35, P=-0.20, Y=-0.01
# Rotasyon (Radyan): R=-0.37, P=-0.20, Y=-0.00
# Rotasyon (Radyan): R=-0.40, P=-0.20, Y=-0.00
# Rotasyon (Radyan): R=-0.44, P=-0.20, Y=-0.00
# Rotasyon (Radyan): R=-0.47, P=-0.20, Y=-0.00
# Rotasyon (Radyan): R=-0.51, P=-0.21, Y=-0.00
# Rotasyon (Radyan): R=-0.55, P=-0.21, Y=-0.00
# Rotasyon (Radyan): R=-0.58, P=-0.21, Y=-0.00
# Rotasyon (Radyan): R=-0.61, P=-0.21, Y=-0.00
# Rotasyon (Radyan): R=-0.64, P=-0.21, Y=-0.00
# Rotasyon (Radyan): R=-0.66, P=-0.20, Y=-0.01
# Rotasyon (Radyan): R=-0.67, P=-0.20, Y=-0.01
# Rotasyon (Radyan): R=-0.68, P=-0.20, Y=-0.01
# Rotasyon (Radyan): R=-0.69, P=-0.20, Y=-0.02
# Rotasyon (Radyan): R=-0.71, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.74, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.77, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.80, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.84, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.87, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.89, P=-0.19, Y=-0.02
# Rotasyon (Radyan): R=-0.91, P=-0.20, Y=-0.01
# Rotasyon (Radyan): R=-0.93, P=-0.21, Y=-0.00
# Rotasyon (Radyan): R=-0.95, P=-0.22, Y=0.02
# Kalibrasyon başladı... Elinizi sabit tutun.
# Rotasyon (Radyan): R=-0.96, P=-0.24, Y=0.03
# Rotasyon (Radyan): R=-0.98, P=-0.26, Y=0.05
# Rotasyon (Radyan): R=-1.01, P=-0.28, Y=0.08
# Rotasyon (Radyan): R=-1.04, P=-0.29, Y=0.10
# Rotasyon (Radyan): R=-1.07, P=-0.30, Y=0.12
# Rotasyon (Radyan): R=-1.10, P=-0.31, Y=0.14
# Rotasyon (Radyan): R=-1.11, P=-0.32, Y=0.15
# Rotasyon (Radyan): R=-1.12, P=-0.34, Y=0.16
# Rotasyon (Radyan): R=-1.12, P=-0.35, Y=0.17
# Rotasyon (Radyan): R=-1.12, P=-0.37, Y=0.17
# Rotasyon (Radyan): R=-1.11, P=-0.38, Y=0.17
# Rotasyon (Radyan): R=-1.11, P=-0.40, Y=0.17
# Rotasyon (Radyan): R=-1.10, P=-0.42, Y=0.17
# Kalibrasyon tamamlandı! Kontrol aktif.
# Rotasyon (Radyan): R=-1.09, P=-0.44, Y=0.16
# Rotasyon (Radyan): R=-1.07, P=-0.46, Y=0.15
# Rotasyon (Radyan): R=-1.06, P=-0.48, Y=0.14
# Rotasyon (Radyan): R=-1.05, P=-0.50, Y=0.13
# Rotasyon (Radyan): R=-1.04, P=-0.52, Y=0.12
# Rotasyon (Radyan): R=-1.03, P=-0.54, Y=0.11
# Rotasyon (Radyan): R=-1.02, P=-0.56, Y=0.10
# Rotasyon (Radyan): R=-1.02, P=-0.58, Y=0.09
# Rotasyon (Radyan): R=-1.01, P=-0.59, Y=0.08
# Rotasyon (Radyan): R=-1.00, P=-0.61, Y=0.07
# Rotasyon (Radyan): R=-1.00, P=-0.62, Y=0.06
# Rotasyon (Radyan): R=-0.99, P=-0.64, Y=0.05
# Kalibrasyon başladı... Elinizi sabit tutun.
# Rotasyon (Radyan): R=-0.99, P=-0.65, Y=0.04
# Rotasyon (Radyan): R=-0.98, P=-0.66, Y=0.04
# Rotasyon (Radyan): R=-0.98, P=-0.67, Y=0.03
# Rotasyon (Radyan): R=-0.98, P=-0.68, Y=0.03
# Rotasyon (Radyan): R=-0.98, P=-0.70, Y=0.03
# Rotasyon (Radyan): R=-0.99, P=-0.71, Y=0.05
# Rotasyon (Radyan): R=-1.01, P=-0.73, Y=0.07
# Rotasyon (Radyan): R=-1.03, P=-0.74, Y=0.09
# Rotasyon (Radyan): R=-1.05, P=-0.75, Y=0.11
# Rotasyon (Radyan): R=-1.06, P=-0.76, Y=0.12
# Rotasyon (Radyan): R=-1.07, P=-0.78, Y=0.13
# Rotasyon (Radyan): R=-1.07, P=-0.79, Y=0.13
# Kalibrasyon tamamlandı! Kontrol aktif.
# Rotasyon (Radyan): R=-1.07, P=-0.80, Y=0.13
# Rotasyon (Radyan): R=-1.07, P=-0.82, Y=0.12
# Rotasyon (Radyan): R=-1.06, P=-0.83, Y=0.12
# Rotasyon (Radyan): R=-1.05, P=-0.85, Y=0.11
# Rotasyon (Radyan): R=-1.04, P=-0.86, Y=0.10
# Rotasyon (Radyan): R=-1.03, P=-0.88, Y=0.09
# Rotasyon (Radyan): R=-1.02, P=-0.89, Y=0.08
# Rotasyon (Radyan): R=-1.01, P=-0.90, Y=0.06
# Rotasyon (Radyan): R=-1.00, P=-0.92, Y=0.05
# Rotasyon (Radyan): R=-0.99, P=-0.93, Y=0.04
# Rotasyon (Radyan): R=-0.98, P=-0.94, Y=0.03
# Rotasyon (Radyan): R=-0.97, P=-0.95, Y=0.02
# Rotasyon (Radyan): R=-0.97, P=-0.96, Y=0.02
# Rotasyon (Radyan): R=-0.98, P=-0.97, Y=0.03
# Rotasyon (Radyan): R=-0.99, P=-0.98, Y=0.04
# Rotasyon (Radyan): R=-1.01, P=-0.99, Y=0.06
# Rotasyon (Radyan): R=-1.02, P=-1.00, Y=0.07
# Rotasyon (Radyan): R=-1.04, P=-1.01, Y=0.09
# Rotasyon (Radyan): R=-1.04, P=-1.02, Y=0.10
# Rotasyon (Radyan): R=-1.05, P=-1.03, Y=0.10
# Rotasyon (Radyan): R=-1.05, P=-1.04, Y=0.10
# Rotasyon (Radyan): R=-1.04, P=-1.06, Y=0.10
# Rotasyon (Radyan): R=-1.04, P=-1.07, Y=0.09
# Rotasyon (Radyan): R=-1.03, P=-1.08, Y=0.08
# Rotasyon (Radyan): R=-1.02, P=-1.09, Y=0.07
# Rotasyon (Radyan): R=-1.00, P=-1.10, Y=0.06
# Rotasyon (Radyan): R=-0.99, P=-1.12, Y=0.04
# Rotasyon (Radyan): R=-0.98, P=-1.13, Y=0.03
# Rotasyon (Radyan): R=-0.97, P=-1.14, Y=0.02
# Rotasyon (Radyan): R=-0.97, P=-1.15, Y=0.03
# Rotasyon (Radyan): R=-1.00, P=-1.17, Y=0.05
# Rotasyon (Radyan): R=-1.03, P=-1.18, Y=0.09
# Rotasyon (Radyan): R=-1.07, P=-1.19, Y=0.12
# Rotasyon (Radyan): R=-1.10, P=-1.20, Y=0.15
# Rotasyon (Radyan): R=-1.11, P=-1.22, Y=0.17
# Rotasyon (Radyan): R=-1.12, P=-1.23, Y=0.18
# Rotasyon (Radyan): R=-1.12, P=-1.25, Y=0.18
# Rotasyon (Radyan): R=-1.11, P=-1.27, Y=0.17
# Rotasyon (Radyan): R=-1.09, P=-1.28, Y=0.15
# Rotasyon (Radyan): R=-1.07, P=-1.30, Y=0.12
# Rotasyon (Radyan): R=-1.03, P=-1.32, Y=0.09
# Rotasyon (Radyan): R=-0.99, P=-1.34, Y=0.04
# Rotasyon (Radyan): R=-0.94, P=-1.36, Y=-0.00
# Rotasyon (Radyan): R=-0.90, P=-1.37, Y=-0.04
# Rotasyon (Radyan): R=-0.89, P=-1.39, Y=-0.05
# Rotasyon (Radyan): R=-0.89, P=-1.40, Y=-0.06
# Rotasyon (Radyan): R=-0.90, P=-1.41, Y=-0.05
# Rotasyon (Radyan): R=-0.92, P=-1.42, Y=-0.03
# Rotasyon (Radyan): R=-0.94, P=-1.42, Y=-0.01
# Rotasyon (Radyan): R=-0.97, P=-1.43, Y=0.01
# Rotasyon (Radyan): R=-0.96, P=-1.43, Y=-0.00
# Rotasyon (Radyan): R=-0.93, P=-1.43, Y=-0.04
# Rotasyon (Radyan): R=-0.87, P=-1.43, Y=-0.10
# Rotasyon (Radyan): R=-0.82, P=-1.43, Y=-0.16
# Rotasyon (Radyan): R=-0.79, P=-1.43, Y=-0.19
# Rotasyon (Radyan): R=-0.79, P=-1.42, Y=-0.20
# Rotasyon (Radyan): R=-0.81, P=-1.42, Y=-0.17
# Rotasyon (Radyan): R=-0.85, P=-1.41, Y=-0.13
# Rotasyon (Radyan): R=-0.91, P=-1.40, Y=-0.08
# Rotasyon (Radyan): R=-0.96, P=-1.39, Y=-0.03
# Rotasyon (Radyan): R=-1.01, P=-1.38, Y=0.02
# Rotasyon (Radyan): R=-1.06, P=-1.38, Y=0.06
# Rotasyon (Radyan): R=-1.10, P=-1.37, Y=0.09
# Rotasyon (Radyan): R=-1.12, P=-1.37, Y=0.11
# Rotasyon (Radyan): R=-1.13, P=-1.37, Y=0.11
# Rotasyon (Radyan): R=-1.13, P=-1.37, Y=0.11
# Rotasyon (Radyan): R=-1.12, P=-1.37, Y=0.10
# Rotasyon (Radyan): R=-1.11, P=-1.37, Y=0.08
# Rotasyon (Radyan): R=-1.08, P=-1.38, Y=0.06
# Rotasyon (Radyan): R=-1.06, P=-1.38, Y=0.03
# Rotasyon (Radyan): R=-1.05, P=-1.38, Y=0.01
# Rotasyon (Radyan): R=-1.07, P=-1.39, Y=0.03
# Rotasyon (Radyan): R=-1.14, P=-1.40, Y=0.10
# Rotasyon (Radyan): R=-1.23, P=-1.40, Y=0.20
# Rotasyon (Radyan): R=-1.32, P=-1.41, Y=0.29
# Rotasyon (Radyan): R=-1.39, P=-1.42, Y=0.36
# Rotasyon (Radyan): R=-1.44, P=-1.43, Y=0.41
# Rotasyon (Radyan): R=-1.47, P=-1.45, Y=0.44
# Rotasyon (Radyan): R=-1.48, P=-1.48, Y=0.45
# Rotasyon (Radyan): R=-1.45, P=-1.51, Y=0.42
# ik_err:[0.0425] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=-1.30, P=-1.54, Y=0.27
# ik_err:[0.0685] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=-0.23, P=-1.56, Y=-0.80
# ik_err:[0.0319] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=0.90, P=-1.54, Y=-1.93
# Rotasyon (Radyan): R=1.12, P=-1.53, Y=-2.15
# Rotasyon (Radyan): R=1.23, P=-1.52, Y=-2.26
# Rotasyon (Radyan): R=1.34, P=-1.52, Y=-2.37
# Rotasyon (Radyan): R=1.47, P=-1.52, Y=-2.50
# Rotasyon (Radyan): R=1.70, P=-1.54, Y=-2.73
# Rotasyon (Radyan): R=2.26, P=-1.55, Y=3.00
# Rotasyon (Radyan): R=2.92, P=-1.54, Y=2.33
# Rotasyon (Radyan): R=3.05, P=-1.54, Y=2.20
# Rotasyon (Radyan): R=2.95, P=-1.53, Y=2.31
# Rotasyon (Radyan): R=2.73, P=-1.52, Y=2.52
# Rotasyon (Radyan): R=2.45, P=-1.52, Y=2.81
# ik_err:[0.0275] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=2.18, P=-1.50, Y=3.07
# ik_err:[0.0624] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=1.96, P=-1.49, Y=-2.99
# ik_err:[0.0275] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=1.81, P=-1.48, Y=-2.84
# Rotasyon (Radyan): R=1.73, P=-1.47, Y=-2.76
# Rotasyon (Radyan): R=1.71, P=-1.47, Y=-2.74
# Rotasyon (Radyan): R=1.73, P=-1.47, Y=-2.76
# Rotasyon (Radyan): R=1.80, P=-1.48, Y=-2.83
# Rotasyon (Radyan): R=1.92, P=-1.50, Y=-2.95
# Rotasyon (Radyan): R=2.17, P=-1.51, Y=3.08
# Rotasyon (Radyan): R=2.50, P=-1.52, Y=2.75
# Rotasyon (Radyan): R=2.69, P=-1.52, Y=2.57
# Rotasyon (Radyan): R=2.70, P=-1.51, Y=2.56
# Rotasyon (Radyan): R=2.58, P=-1.51, Y=2.67
# Rotasyon (Radyan): R=2.39, P=-1.50, Y=2.87
# ik_err:[0.0268] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=2.17, P=-1.49, Y=3.08
# ik_err:[0.0617] is higher than ik_err_th:[0.0100].
# You may want to increase max_ik_tick:[2000]
# Rotasyon (Radyan): R=1.98, P=-1.48, Y=-3.00
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# using IP Camera
def camera_thread():
    global action, gripper_state_, final_rel_angles, coords_, dir
    
    cap = cv2.VideoCapture("http://192.168.1.6:8080/video")
    address = "https://192.168.1.6:8080/video"
    cap.open(address)
    # cap = cv2.VideoCapture(0)

    # cap = cv2.VideoCapture(0)
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.flip(frame, 1)
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        detection_result = detector.detect(mp_image)
        
        res = draw_landmarks_on_image(rgb_frame, detection_result)
        annotated_frame, state_, final_rel_angles, coords_, dir = res
        gripper_state_ = bool(state_)

        cv2.imshow('Hand Orientation', cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()


def sim_thread():
    global action, coords_, final_rel_angles, dir
    hand_z_cm_= 0
    

    xml_path = './asset/trossen_vx300s/scene.xml'
    PnPEnv = SimpleEnv(xml_path, seed = 0, state_type = 'joint_angle')
    new_plate_pos = np.array([10.5, 0.2, 0.0])
    new_mug_pos = np.array([0.50, -0.0, 0.05]) # Kupa da masada kalsın
    PnPEnv.set_obj_pose(p_mug=new_mug_pos, p_plate=new_plate_pos)

    action = np.zeros(7)    
    reset = False
        
    while PnPEnv.env.is_viewer_alive():
        PnPEnv.step_env()
        if PnPEnv.env.loop_every(HZ=50):
            curr_ee_pose = PnPEnv.get_ee_pose()

            current_gripper = gripper_state_
            hand_x_cm, hand_y_cm, hand_z_cm = coords_
            hand_y_cm = -hand_y_cm
            
            # print("[INFO].. ",hand_x_cm, hand_y_cm, hand_z_cm)

            if abs(hand_z_cm) > 35:
                hand_z_cm_ = (35 - hand_z_cm) * 3.0

            elif 10 < abs(hand_z_cm) < 30:
                hand_z_cm_ = (30 - hand_z_cm) * 0.8
            else:
                hand_z_cm_ = 0
            # print("[INFO].. ",hand_x_cm, hand_y_cm, hand_z_cm)
            
            # wrist_x = -final_rel_angles[0]
            wrist_y = -final_rel_angles[1]
            # wrist_z = final_rel_angles[2]

            # print("wrist x: ", wrist_x)
            # print("wrist y: ", wrist_y)
            # print("wrist z: ", wrist_z)

            if dir == "right":
                wrist_x = 90
            elif dir == "left":
                wrist_x = -90
            else:
                wrist_x=0

            
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, 
            #                                            w_pitch = wrist_y, w_roll = wrist_x , w_yaw = 0.0, 
            #                                            w_x = hand_z_cm_, w_y = hand_x_cm, w_z = hand_y_cm*1.3)
            # w_x = hand_y_cm


            action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, 
                                                       w_pitch = 0, w_roll = wrist_x , w_yaw = 0.0, 
                                                       w_x = hand_y_cm, w_y = 0.0, w_z = hand_z_cm_)


            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=0.0, w_y=0.0, w_z = hand_y_cm)
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=hand_z_cm, w_y=0.0, w_z = 0.0)
            # action, reset  = PnPEnv.test_teleop_robot1(gripper_state=current_gripper, w_pitch = 0.0, w_roll = 0.0 , w_yaw= 0.0, w_x=0.0, w_y=hand_x_cm, w_z = 0.0)


            if reset:
                PnPEnv.reset(seed=0)

            # Get the end-effector pose and images
            ee_pose = PnPEnv.get_ee_pose()

            # İlk 3 eleman pozisyon (x, y, z), son 3 eleman rotasyon (roll, pitch, yaw)
            px, py, pz, roll, pitch, yaw = ee_pose
            # print(f"Pozisyon: X={px:.2f}, Y={py:.2f}, Z={pz:.2f}")
            print(f"Rotasyon (Radyan): R={roll:.2f}, P={pitch:.2f}, Y={yaw:.2f}")
                        

            agent_image,wrist_image = PnPEnv.grab_image()

            # resize to 256x256
            agent_image = Image.fromarray(agent_image)
            wrist_image = Image.fromarray(wrist_image)

            agent_image = agent_image.resize((256, 256))
            wrist_image = wrist_image.resize((256, 256))

            agent_image = np.array(agent_image)
            wrist_image = np.array(wrist_image)

            joint_q = PnPEnv.step(action)

            PnPEnv.render(teleop=True)

    PnPEnv.env.close_viewer()

# Start threads
t1 = threading.Thread(target=camera_thread)
t2 = threading.Thread(target=sim_thread)
t1.start()
t2.start()
t1.join()
t2.join()
